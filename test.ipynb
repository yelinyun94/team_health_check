# %%
import pandas as pd

# Replace 'health_check.xlsx' with the actual path to your Excel file
file_path = 'health_check_2.xlsx'

# Load the Excel file into a DataFrame
df = pd.read_excel(file_path)

pd.DataFrame(df)
# Out:
#            Category / Team Telephony Conferencing
# 0         Delivering Value     Green          Red
# 1    Operational Stability    Green         Green
# 2                      Fun      Red         Green
# 3   Provider Collaboration    Yellow        Green
# 4                 Learning     Green          Red
# 5                  Mission     Green       Yellow
# 6        Pawns or Playyers      Red         Green
# 7                    Speed    Yellow        Green
# 8         Suitable Process     Green          Red
# 9                  Support     Green       Yellow
# 10                Teamwork       Red        Green
